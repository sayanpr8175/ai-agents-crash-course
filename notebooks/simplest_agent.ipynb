# %% [markdown]
# # Creating a Simple Agent with Tracing

# %%
import dotenv
import os

from openai import OpenAI

dotenv.load_dotenv()

if not os.environ.get("OPENAI_API_KEY"):
    print("Issue with the OPENAI_api_key")

print(
    OpenAI()
    .responses.create(
        model=os.environ["OPENAI_DEFAULT_MODEL"], input="Say: We are up and running!"
    )
    .output_text
)
# Out:
# We are up and running!

# %%
from agents import Agent, Runner, trace
from openai.types.responses import ResponseTextDeltaEvent

# %%
from agents import Agent, Runner, trace
from openai.types.responses import ResponseTextDeltaEvent

# %% [markdown]
# Create a simple Nutrition Assistant Agent

# %%
nutrition_agent = Agent(
    name="Nutrition Assistant",
    instructions="""
    You are a helpful assistant giving out nutrition advice.
    You give concise answers.
    """
)

# %% [markdown]
# Let's execute the Agent:

# %%
with trace("Simple Nutrition Agent"):
    result = await Runner.run(nutrition_agent, "How good chips ahoy cookies are? and who makes them?")

print(result)
# Out:
# RunResult:
# - Last agent: Agent(name="Nutrition Assistant", ...)
# - Final output (str):
#     Chips Ahoy! are a popular mass-market chocolate chip cookie brand made by Mondelez International (Nabisco brand).
#
#     They’re convenient and tasty, with many varieties (Original, Chewy, Thick & Soft, etc.). They’re generally high in sugar and fat, so they’re best enjoyed in moderation as an occasional treat.
# - 2 new item(s)
# - 1 raw response(s)
# - 0 input guardrail result(s)
# - 0 output guardrail result(s)
# (See `RunResult` for more details)

# %%
with trace("Simple Nutrition Agent"):
    result = await Runner.run(nutrition_agent, "How healthy are bananas?")

print(result)
# Out:
# RunResult:
# - Last agent: Agent(name="Nutrition Assistant", ...)
# - Final output (str):
#     Generally healthy and nutrient-dense.
#
#     - Pros: good source of potassium, fiber, vitamin C, vitamin B6; provides quick energy; can help digestion and heart health.
#     - Considerations: natural sugars (watch portion if you’re tracking carbs/diabetes); ripeness changes starch vs sugar; moderate calories (about 90–120 kcal per medium banana).
#     - Bottom line: they’re a healthy part of a balanced diet when eaten in appropriate portions.
# - 2 new item(s)
# - 1 raw response(s)
# - 0 input guardrail result(s)
# - 0 output guardrail result(s)
# (See `RunResult` for more details)

# %% [markdown]
# Streaming the answer to the screen, token by token

# %%
response_stream = Runner.run_streamed(nutrition_agent, "How healthy are bananas?")

async for event in response_stream.stream_events():
    if event.type == "raw_response_event" and isinstance(
        event.data, ResponseTextDeltaEvent
    ):
        print(event.data.delta, end="", flush=True)
# Out:
# Overall, bananas are healthy.
#
# - Benefits: good source of potassium, vitamin C, vitamin B6, and dietary fiber; low in fat. Provide quick energy and can support heart health and digestion.
# - Considerations: they contain natural sugars; ripe bananas are sweeter. People with diabetes should watch portion size.
# - Quick tips: 1 medium banana per day fits most diets; pair with protein or fat to balance blood sugar. Unripe bananas have resistant starch, which acts like fiber.
#
# If you have specific health goals or conditions, I can tailor advice.

# %% [markdown]
# _Good Job!_
